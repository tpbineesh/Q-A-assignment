# %%
1#Read the dataset to python environment.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars_data=pd.read_csv('/content/cars_data.csv')
cars_data
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %%
2#Check for the null values present in the dataset.
cars_data2=cars_data.isnull()
cars_data2
# Out:
#        Make  Model  Nickname  ...  5-yr Depreciation  Top Speed  0-60 Time
# 0     False  False     False  ...              False      False      False
# 1     False  False     False  ...              False      False      False
# 2     False  False     False  ...              False      False      False
# 3     False  False     False  ...              False      False      False
# 4     False  False     False  ...              False      False      False
# ...     ...    ...       ...  ...                ...        ...        ...
# 9995  False  False     False  ...              False      False      False
# 9996  False  False     False  ...              False      False      False
# 9997  False  False     False  ...              False      False      False
# 9998  False  False     False  ...              False      False      False
# 9999  False  False     False  ...              False      False      False
#
# [10000 rows x 20 columns]

# %%
#3 Plot a bar graph of male vs female buyers participated in the sales.
cars_data['Buyer Gender'].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %%
data={'Gender':['Male','Female'],'Frequency':[4948,5052]}
data2=pd.DataFrame(data)
data2
# Out:
#    Gender  Frequency
# 0    Male       4948
# 1  Female       5052

# %%
sns.barplot(x='Gender',y='Frequency',data=data2)
plt.title('Male vs Female Buyers')
# Out:
# Text(0.5, 1.0, 'Male vs Female Buyers')

# %%
#4.Find the top 5 cars based on their sales price
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/cars_data.csv')
df
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %%
final_data=df.drop(['Model', 'Nickname', 'Car Gender', 'Buyer Gender','Buyer Age',
       'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
       'Color', 'New Car', 'Purchase Date','Discount',
       'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],axis=1)
final_data
# Out:
#          Make  Sale Price
# 0      Suzuki    54806.14
# 1       Honda    51826.30
# 2         BMW    82929.14
# 3      Toyota    56928.66
# 4        Ford    77201.26
# ...       ...         ...
# 9995    Mazda    58580.65
# 9996      GMC    75229.74
# 9997  Mercury    34755.44
# 9998   Daewoo    98725.42
# 9999   Toyota    96769.78
#
# [10000 rows x 2 columns]

# %%
sort=final_data.nlargest(5,'Sale Price')
sort
# Out:
#             Make  Sale Price
# 5984  Volkswagen    99997.65
# 1270        Audi    99991.91
# 3460       Lexus    99983.38
# 9032       Mazda    99978.17
# 302        Lexus    99973.44

# %%
#5 Find the least 5 cars based on their Resell price.
final_data2=df.drop(['Model', 'Nickname', 'Car Gender', 'Buyer Gender','Buyer Age',
       'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
       'Color', 'New Car', 'Purchase Date','Sale Price','Discount',
        '5-yr Depreciation', 'Top Speed', '0-60 Time'],axis=1)
final_data2
# Out:
#          Make  Resell Price
# 0      Suzuki      33858.32
# 1       Honda       2989.28
# 2         BMW      35049.16
# 3      Toyota       8236.15
# 4        Ford      32765.76
# ...       ...           ...
# 9995    Mazda      42640.82
# 9996      GMC      21115.58
# 9997  Mercury       2731.25
# 9998   Daewoo      18718.58
# 9999   Toyota       4545.95
#
# [10000 rows x 2 columns]

# %%
sort2=final_data2.nsmallest(5,'Resell Price')
sort2
# Out:
#             Make  Resell Price
# 2446   Chevrolet       2000.84
# 4933         GMC       2005.44
# 566       Jaguar       2014.09
# 2538  Mitsubishi       2017.24
# 5869    Infiniti       2017.83
